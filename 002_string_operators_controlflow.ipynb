# %% [markdown]
# # String operations

# %%
name ="Zaheer jk  "

# %%
name=name.strip()
name

# %%
name="   zaheer jk   "
name.rstrip()

# %%
name.lstrip()

# %%
name="   zaheer jk   "
name=name.lstrip()
name=name.strip()
name

# %%
name="   zaheer jk   "
name=name.lstrip().rstrip()
name

# %%
name="   zaheer jk   "
name=name.rstrip().lstrip()
name

# %% [markdown]
# # Operators

# %% [markdown]
# #### Relational operators

# %%
a=100
b=200

# %%
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)

# %%
a="Data"
b="Data "
print(a==b)

# %%
id=123
passoword="HelloWorld"
print(id==100)
print(passoword=="StrongPassoword")

# %%
age_threeshold=18
person_1_age=18
print(person_1_age>=person_1_age)

# %% [markdown]
# #### Assignment operator

# %%
a=2
print(a)

# %%
a+=1
print(a)

# %%
a-=1
print(a)

# %%
a*=2
print(a)

# %%
a/=2
print(a)

# %%
a/0.3

# %%
a//=0.3
print(a)

# %% [markdown]
# # Logical Operators

# %%
bool_a=True
bool_b=False

# %%
bool_a and bool_b

# %%
bool_a or bool_b

# %%
not bool_b

# %%
not bool_a

# %%
person_age=20
person_threshold=18


min_balance=500
person_balance=600
print(person_age>=person_threshold and person_balance>=min_balance)

# %% [markdown]
# #### bitwise operators

# %% [markdown]
# #### Conditional Statements or Control flow

# %%
current_batch=3
if current_batch==2:
    print("Acess to USD batch 1.0 also provided")
else:
    print("You only have aceess to USD batch 1.0")

# %%
current_batch=3
if current_batch==2:
    print("Acess to USD batch 1.0 also provided")

a=2
b=2
print(a+b)

# %%
current_batch=3
if current_batch==2:
    print("Acess to USD batch 1.0 also provided")
else:
    print("You only have aceess to USD batch 1.0")

a=2
b=2
print(a+b)

# %%
if True:
    print("Hello")

# %% [markdown]
# #### if-elif-else

# %%
operation_name="divide"

if operation_name=="add":
    print("Addition")
elif operation_name=="substract":
    print("Perform Division")
elif operation_name=="divide":
    print("Perform division")
else:
    print("No selected operation name found")

# %%
operation_name="add"

if operation_name=="add":
    print("perform addition")


if operation_name=="add":
    print("perform addition")
elif operation_name=="substract":
    print("perform substract")
elif operation_name=="divide":
    print("perfrom division")
else:
    print("No selected opeation name Found")

# %%
age=19
batch=2.0
session_number=4


if age>19:
    print("19")



if batch>1.0:
    print("Gives acces to v1.0")


if session_number>1:
    print("Induction Class ended")

# %% [markdown]
# # More data types

# %%
id_people=[100,101,102,103,104,105]

# %%
print(id_people)

# %%
people=[101,100,102,"A","b",37.4,True]

# %%
print(people)

# %%
print(type(people))

# %%
people.append("Data Science")

# %%
print(people)

# %%
register=[]
print(type(register))

# %%
register.append(["zaheer",101,"+01234567890","visit"])

# %%
print(register)

# %%
register.append(["pradeep",101,"+911234567890","Visit"])

# %%
print(register)

# %% [markdown]
# ### experimentation on list

# %%
dummy=[]

# %%
print(dummy)

# %%
dummy.append([1,2,3,4,"hello","monal",101])

# %%
len(dummy)
