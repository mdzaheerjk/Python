# %% [markdown]
# # Non-Primitive Data Types

# %%
l=["hello","hey","Python",10,False]

# %%
print(l[3])
# Out:
# 10

# %%
print(l[0])
# Out:
# hello

# %%
print(l[0])
# Out:
# hello

# %%
print(l[-2])
# Out:
# 10

# %%
len("Data")
# Out:
# 4

# %%
len(l)
# Out:
# 5

# %%
l[len(l)-1]
# Out:
# False

# %%
l[-1]
# Out:
# False

# %%
l
# Out:
# ['hello', 'hey', 'Python', 10, False]

# %%
l.pop()
# Out:
# False

# %%
l.append(True)

# %%
l
# Out:
# ['hello', 'hey', 'Python', 10, True]

# %%
l.pop(0)
# Out:
# 'hello'

# %%
l
# Out:
# ['hey', 'Python', 10, True]

# %%
l
# Out:
# ['hey', 'Python', 10, True]

# %%
l[0]='python 3.15'

# %%
l
# Out:
# ['python 3.15', 'Python', 10, True]

# %%
l.append('Hey')

# %%
l
# Out:
# ['python 3.15', 'Python', 10, True, 'Hey']

# %%
l.remove('Hey')

# %%
l
# Out:
# ['python 3.15', 'Python', 10, True]

# %%
l.insert(2,"Machine Learning")

# %%
l
# Out:
# ['python 3.15', 'Python', 'Machine Learning', 10, True]

# %% [markdown]
# ### Dictionary

# %%
register={
    "rohit":['12-12-1980',1234567890,'abcdefg'],
    "rohith":['12-12-1981',1234567890,'abcdefg'],
    "zaheer":False
}

# %%
print(register)
# Out:
# {'rohit': ['12-12-1980', 1234567890, 'abcdefg'], 'rohith': ['12-12-1981', 1234567890, 'abcdefg'], 'zaheer': False}

# %%
government_sys={
    101:["zaheer"],
    102:["Amit"],
    103:["Dhaval"],
    104:["Surya"]
}

# %%
government_sys.get(101)
# Out:
# ['zaheer']

# %%
government_sys.get(110,"Value does not present")
# Out:
# 'Value does not present'

# %%
government_sys[101]
# Out:
# ['zaheer']

# %%
government_sys.keys()
print(list(government_sys.keys()))
# Out:
# [101, 102, 103, 104]

# %%
government_sys.values()
print(list(government_sys.values()))
# Out:
# [['zaheer'], ['Amit'], ['Dhaval'], ['Surya']]

# %%
for i in government_sys.keys():
    print(i)
# Out:
# 101
# 102
# 103
# 104

# %%
for i in government_sys.values():
    print(i)
# Out:
# ['zaheer']
# ['Amit']
# ['Dhaval']
# ['Surya']

# %% [markdown]
# ### Tuple

# %%
empty_tuple=()

# %%
print(empty_tuple)
# Out:
# ()

# %%
empty_tuple=tuple()
print(type(empty_tuple))
# Out:
# <class 'tuple'>

# %%
dob=(10,"feb",1920)

# %%
print(type(dob))
# Out:
# <class 'tuple'>

# %%
dob
# Out:
# (10, 'feb', 1920)

# %%
dob[0]
# Out:
# 10

# %%
register_v2={
    101:{
        "name":"zaheer",
        "dob":(10,'feb','1920'),
        "phone no":"+01 -1111111111"
    },
    102:{
        "Name":"ashish",
        "dob":(10,'feb','1990'),
        "phone no":"+91-1111111111"
    }
}

# %%
register_v2[101]
# Out:
# {'name': 'zaheer', 'dob': (10, 'feb', '1920'), 'phone no': '+01 -1111111111'}
